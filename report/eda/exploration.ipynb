# %% [markdown]
# # Explore data
#
# ## Import libraries

# %%
# %config IPCompleter.greedy=True
# libraries
import pandas as pd
import numpy as np
from plotnine import *

# %% [markdown]
# ## Load the data

# %%
train_data = pd.read_csv("../../data/raw/trainingData.csv")
val_data = pd.read_csv("../../data/raw/validationData.csv")

# %%
train_data.head()
# Out:
#    WAP001  WAP002  WAP003  WAP004  WAP005  WAP006  WAP007  WAP008  WAP009  \
# 0     100     100     100     100     100     100     100     100     100
# 1     100     100     100     100     100     100     100     100     100
# 2     100     100     100     100     100     100     100     -97     100
# 3     100     100     100     100     100     100     100     100     100
# 4     100     100     100     100     100     100     100     100     100
#
#    WAP010  ...  WAP520  LONGITUDE      LATITUDE  FLOOR  BUILDINGID  SPACEID  \
# 0     100  ...     100 -7541.2643  4.864921e+06      2           1      106
# 1     100  ...     100 -7536.6212  4.864934e+06      2           1      106
# 2     100  ...     100 -7519.1524  4.864950e+06      2           1      103
# 3     100  ...     100 -7524.5704  4.864934e+06      2           1      102
# 4     100  ...     100 -7632.1436  4.864982e+06      0           0      122
#
#    RELATIVEPOSITION  USERID  PHONEID   TIMESTAMP
# ...

# %% [markdown]
# We need to define the goals to approach the task:
#
# * First create a model based on Building 1
# * Plot the buildings

# %%
(ggplot() + 
    aes(y = "LATITUDE", x = "LONGITUDE") +
    geom_point(data = train_data, color = "darkgreen", alpha = 0.3) +
    geom_point(data = val_data, color = "firebrick", alpha = 0.3) +
    theme_bw())
# Out:
# <ggplot: (8744010857869)>
